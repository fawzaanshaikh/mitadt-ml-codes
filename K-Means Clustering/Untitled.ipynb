# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('sobar-72.csv')

# %%
df.head()
# Out:
#    behavior_sexualRisk  behavior_eating  behavior_personalHygine  \
# 0                   10               13                       12
# 1                   10               11                       11
# 2                   10               15                        3
# 3                   10               11                       10
# 4                    8               11                        7
#
#    intention_aggregation  intention_commitment  attitude_consistency  \
# 0                      4                     7                     9
# 1                     10                    14                     7
# 2                      2                    14                     8
# 3                     10                    15                     7
# 4                      8                    10                     7
#
#    attitude_spontaneity  norm_significantPerson  norm_fulfillment  \
# 0                    10                       1                 8
# 1                     7                       5                 5
# 2                    10                       1                 4
# 3                     7                       1                 5
# 4                     8                       1                 5
#
#    perception_vulnerability  perception_severity  motivation_strength  \
# 0                         7                    3                   14
# 1                         4                    2                   15
# 2                         7                    2                    7
# 3                         4                    2                   15
# 4                         3                    2                   15
#
#    motivation_willingness  socialSupport_emotionality  \
# 0                       8                           5
# 1                      13                           7
# 2                       3                           3
# 3                      13                           7
# 4                       5                           3
#
#    socialSupport_appreciation  socialSupport_instrumental  \
# 0                           7                          12
# 1                           6                           5
# 2                           6                          11
# 3                           4                           4
# 4                           6                          12
#
#    empowerment_knowledge  empowerment_abilities  empowerment_desires  \
# 0                     12                     11                    8
# 1                      5                      4                    4
# 2                      3                      3                   15
# 3                      4                      4                    4
# 4                      5                      4                    7
#
#    ca_cervix
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
km=KMeans(n_clusters=2, max_iter=400,verbose=True,tol=0.2)
pred = km.fit_predict(df[['behavior_sexualRisk','behavior_eating','behavior_personalHygine','intention_aggregation','intention_commitment','attitude_consistency','attitude_spontaneity','norm_significantPerson','norm_fulfillment','perception_vulnerability','perception_severity','motivation_strength','motivation_willingness','socialSupport_emotionality','socialSupport_appreciation','socialSupport_instrumental','empowerment_knowledge','empowerment_abilities','empowerment_desires']])
# plt.scatter(df['B'], df['C'],c=df['A'])
score = accuracy_score(df['ca_cervix'], pred)
score
# Out:
# Initialization complete
# Iteration 0, inertia 20332.0
# Iteration 1, inertia 11264.773073642038
# Iteration 2, inertia 10880.444346387203
# Converged at iteration 2: center shift 1.2510068530048566 within tolerance 2.2867690058479537.
# Initialization complete
# Iteration 0, inertia 18061.0
# Iteration 1, inertia 11760.662728836578
# Iteration 2, inertia 10920.364363083436
# Iteration 3, inertia 10751.108111779442
# Converged at iteration 3: center shift 1.0147178548072389 within tolerance 2.2867690058479537.
# Initialization complete
# Iteration 0, inertia 19182.0
# Iteration 1, inertia 10840.339504132233
# Iteration 2, inertia 10689.026282578876
# Converged at iteration 2: center shift 0.363405363097522 within tolerance 2.2867690058479537.
# Initialization complete
# Iteration 0, inertia 19162.0
# Iteration 1, inertia 11113.779510011598
# Iteration 2, inertia 10883.402068017454
# Iteration 3, inertia 10721.945422952616
# Converged at iteration 3: center shift 1.5294983633239687 within tolerance 2.2867690058479537.
# Initialization complete
# Iteration 0, inertia 20549.0
# Iteration 1, inertia 10752.599839615075
# Iteration 2, inertia 10671.477145148356
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 22558.0
# Iteration 1, inertia 12166.076991735537
# Iteration 2, inertia 10809.269574759946
# Iteration 3, inertia 10697.187373192053
# Converged at iteration 3: center shift 0.6168711380640044 within tolerance 2.2867690058479537.
# Initialization complete
# Iteration 0, inertia 22278.0
# Iteration 1, inertia 12625.402850597628
# Converged at iteration 1: center shift 0.6496840287598505 within tolerance 2.2867690058479537.
# Initialization complete
# Iteration 0, inertia 16752.0
# Iteration 1, inertia 11210.9476061093
# Iteration 2, inertia 10725.935064935065
# Converged at iteration 2: center shift 1.114648338674312 within tolerance 2.2867690058479537.
# Initialization complete
# Iteration 0, inertia 24111.0
# Iteration 1, inertia 10745.209108843961
# Converged at iteration 1: center shift 1.224645417991005 within tolerance 2.2867690058479537.
# Initialization complete
# Iteration 0, inertia 21700.0
# Iteration 1, inertia 12470.48768798704
# Iteration 2, inertia 12350.371517027865
# Converged at iteration 2: strict convergence.
# 0.7777777777777778

# %%
plt.scatter(df['behavior_eating'], df['behavior_personalHygine'],c=pred)
plt.scatter(km.cluster_centers_[:,0] ,km.cluster_centers_[:,1], color='black')
